# %%
from rixs import *
# import cdw_gap

# %%
Mysystem = System(paras,1000)
Mysystem.paras.delta=20

# %%
# b1g
x = np.array([0.05, 0.1, 0.15, 0.18, 0.2, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.287])/(Mysystem.paras.norm / (np.pi * 2))
y = np.linspace(-50,110, 400)
Mysystem.paras.delta = 1
#X,Y,Z_b1g = Mysystem.intensity_mesh(x,y, mode='b1g', isfast = False)
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_b1g,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

Z_b1g[Y<0]=0
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_b1g,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

np.savetxt('C:/Users/51910/OneDrive/1UZH/2Projects/lesco_project/simulation_data/Z_b1g.txt', 1000*Z_b1g, delimiter=' ', fmt='%f')

# %%
# ap
x = np.array([0.05, 0.1, 0.15, 0.18, 0.2, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.287])/(Mysystem.paras.norm / (np.pi * 2))
y = np.linspace(-50,110, 400)
Mysystem.paras.delta = 1
X,Y,Z_ap = Mysystem.intensity_mesh(x,y, mode='ap', isfast = False)
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_ap,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

Z_ap[Y<0]=0
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_ap,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

np.savetxt('C:/Users/51910/OneDrive/1UZH/2Projects/lesco_project/simulation_data/X.txt', X, delimiter=' ', fmt='%f')
np.savetxt('C:/Users/51910/OneDrive/1UZH/2Projects/lesco_project/simulation_data/Y.txt', Y, delimiter=' ', fmt='%f')
np.savetxt('C:/Users/51910/OneDrive/1UZH/2Projects/lesco_project/simulation_data/Z_ap.txt', 1000*Z_ap, delimiter=' ', fmt='%f')
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]
# c:\Users\51910\OneDrive\1UZH\2Projects\lesco_mess\fitting_method4\rixs.py:356: ComplexWarning: Casting complex values to real discards the imaginary part
#   I[j,i] = self.intensity(q, omega, mode = mode, isfast = isfast, isold = isold)
# 100%|██████████| 400/400 [3:08:03<00:00, 28.21s/it]

# %%
# br
x = np.array([0.05, 0.1, 0.15, 0.18, 0.2, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.287])/(Mysystem.paras.norm / (np.pi * 2))
y = np.linspace(-50,110, 400)
Mysystem.paras.delta = 1
X,Y,Z_br = Mysystem.intensity_mesh(x,y, mode='br', isfast = False)
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_br,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

Z_br[Y<0]=0
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_br,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

np.savetxt('C:/Users/51910/OneDrive/1UZH/2Projects/lesco_project/simulation_data/Z_br.txt', 1000*Z_br, delimiter=' ', fmt='%f')
# Out:
# 100%|██████████| 400/400 [2:36:00<00:00, 23.40s/it]

# %%
# a1g
x = np.array([0.05, 0.1, 0.15, 0.18, 0.2, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.287])/(Mysystem.paras.norm / (np.pi * 2))
y = np.linspace(-50,110, 400)
Mysystem.paras.delta = 1
# X,Y,Z_a1g = Mysystem.intensity_mesh(x,y, mode='a1g', isfast = False)
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_br,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

Z_a1g[Y<0]=0
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_a1g,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')

# np.savetxt('C:/Users/51910/OneDrive/1UZH/2Projects/lesco_project/simulation_data/Z_a1g.txt', 1000*Z_a1g, delimiter=' ', fmt='%f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # a1g
# ----> 2 x = np.array([0.05, 0.1, 0.15, 0.18, 0.2, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.287])/(Mysystem.paras.norm / (np.pi * 2))
#       3 y = np.linspace(-50,110, 400)
#       4 Mysystem.paras.delta = 1
#
# NameError: name 'np' is not defined

# %%
np.savetxt('X.txt', X, delimiter=' ', fmt='%f')
np.savetxt('Y.txt', Y, delimiter=' ', fmt='%f')
#np.savetxt('Z_ap.txt', 1000*Z_ap, delimiter=' ', fmt='%f')
# np.savetxt('Z_ac.txt', 1000*Z_ac, delimiter=' ', fmt='%f')
np.savetxt('Z_a1g.txt', 1000*Z_a1g, delimiter=' ', fmt='%f')
# np.savetxt('Z_b1g.txt', 1000*Z_b1g, delimiter=' ', fmt='%f')
# np.savetxt('Z_br.txt', 1000*Z_br, delimiter=' ', fmt='%f')
# np.savetxt('Z_ap.txt', 1000*Z_ap, delimiter=' ', fmt='%f')

# %%
# a1g
Mysystem.paras.OMEGA['a1g'] = 52
Mysystem.paras.delta = 1
x = np.linspace(0,0.3,20)/(Mysystem.paras.norm / (np.pi * 2))
y = np.linspace(-50,150, 100)
X,Y,Z_a1g = Mysystem.intensity_mesh(x,y, mode='a1g', isfast = True)
plt.figure(figsize = (3,3))
plt.pcolor(X*Mysystem.paras.norm / (np.pi * 2),Y,Z_a1g,cmap = 'inferno')
plt.xlabel('$q_{h}$ (r.l.u)')
plt.ylabel('Energy (eV)')
# Out:
# 100%|██████████| 50/50 [00:04<00:00, 10.58it/s]
# Text(0, 0.5, 'Energy (eV)')

# %%
np.savetxt('Z_a1g_refined.txt', 1000*Z_a1g, delimiter=' ', fmt='%f')

# %% [markdown]
# x = np.linspace(0,1,100)

# %%
x = np.linspace(0,2,1000)

# %%
y = (1+x)**2/(1+4*x)
plt.plot(x,y)

# %%
def foo():
    def fo(x,y):
        return x+y
    return fo

# %%
a = foo()

# %%
a(1,2)
# Out:
# 3
